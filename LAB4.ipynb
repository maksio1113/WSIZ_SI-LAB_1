# %% [markdown]
# <a href="https://colab.research.google.com/github/maksio1113/WSIZ_SI-LAB_1/blob/master/LAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_openml

samochody = fetch_openml('cars1')
samochody.keys()
X = samochody.data[:, [0, 3]]
y = samochody['target']
y = [int(elem) for elem in y]
y[:10]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
kmn = KMeans(n_clusters=3)
kmn.fit(X_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
centra = kmn.cluster_centers_
fig, ax = plt.subplots(1, 2)
ax[0].scatter(X_train[:, 0], X_train[:, 1], c=y_train, s=20)
y_pred_train = kmn.predict(X_train)
ax[1].scatter(X_train[:, 0], X_train[:, 1], c=y_pred_train, s=20)
ax[1].scatter(centra[:, 0], centra[:, 1], c='red', s=50)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y_pred = kmn.predict(X_test)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, s=20)
plt.scatter(centra[:, 0], centra[:, 1], c='red', s=50)
plt.show()

# %% [markdown]
# Według mnie w zbiorze znalazły się 3 klasy aut: jedne są to auta o małym silniku i zużywające mało paliwa,drugie zużywają więcej, a ostatnie najwięcej paliwa przy odpowiednio dużym silniku.
